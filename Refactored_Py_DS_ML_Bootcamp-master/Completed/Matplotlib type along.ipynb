# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x **2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Function
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r-')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# 00
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('Your mama')

axes2.plot(y,x)
axes2.set_title('Help')
# Out:
# Text(0.5, 1.0, 'Help')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

#axes.plot(x,y)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027F01F62FC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027F020C9308>],
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows =1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('First Plot')
# Out:
# Text(0.5, 1.0, 'First Plot')

# %%
fig,axes = plt.subplots(nrows = 2, ncols =1, figsize=(8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
fig

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label='X Squared')
ax.plot(x,x**3, label='X Cubed')

ax.legend(loc = (0.1,0.1))

# %%
fig.savefig('my_picture.png',dpi = 200)

# %% [markdown]
# # Plot Appearance

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color='purple', linewidth =2, ls='--',marker='o', markersize=20, markeredgewidth = 3, markeredgecolor='green')
axset._xlim([0,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-8bdc0a2c8d7d> in <module>
#       4
#       5 ax.plot(x,y, color='purple', linewidth =2, ls='--',marker='o', markersize=20, markeredgewidth = 3, markeredgecolor='green')
# ----> 6 axset._xlim([0,1])
#
# NameError: name 'axset' is not defined
