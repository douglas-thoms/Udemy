# %% [markdown]
# First build board with index
# See if numbers update as expected
# Create a function that
# input - takes position and alternates in 0 and 1
# process - updates list,adds to board
# checks if 3 in a row
# output prints board
#
# bonus add on numpad gui to input

# %%
entries = [" "," "," "," "," "," "," "," "," "]
print(" {}|{}|{}\n -----\n {}|{}|{}\n -----\n {}|{}|{}".format(entries[0],
                                               entries[1],
                                               entries[2],
                                               entries[3],
                                               entries[4],
            
                                                               entries[5],
                                               entries[6],
                                               entries[7],
                                               entries[8]))

while True:
    try:
        number = int(input("Enter number 1-9:"))
        if number < 1 or number > 9:
            raise ValueError("Not within range of 1-9")
    except ValueError as ve:
        print(ve)
        continue
    else: 
        print ("Acceptable")
        break

while True:
    try:
        xo = str(input("Enter \"X\" or \"O\":"))
        if xo !="X" and xo !="O":
            raise ValueError("Not X or O")
    except ValueError as ve:
        print(ve)
        continue
    else: 
        print ("Acceptable")
        break
        
entries[number] = xo
print(entries)
print(" {}|{}|{}\n -----\n {}|{}|{}\n -----\n {}|{}|{}".format(entries[0],
                                               entries[1],
                                               entries[2],
                                               entries[3],
                                               entries[4],
                                               entries[5],
                                               entries[6],
                                               entries[7],
                                               entries[8]))

# %%
#if entries[0] == entries[1] == entries[2]
    print("You win")

def tictactoe(a,b,c):
    threeMoves = set(a,b,c)
    winningCombo = list(set(0,3,6))
    #while threeInRow == False:
    if threeMoves in winningCombo:
    #if threeMoves in moves.add(num)
        print(True)

# %%
def determineWinner(entries):
    if entries[0]==entries[1]==entries[2] and (entries[0] == "X" or entries[0] == "O"):
        return True
    elif entries[0]==entries[3]==entries[6] and (entries[0] == "X" or entries[0] == "O"):
        return True
    elif entries[0]==entries[4]==entries[8] and (entries[0] == "X" or entries[0] == "O"):
        return True
    elif entries[1]==entries[4]==entries[7] and (entries[1] == "X" or entries[1] == "O"):
        return True
    elif entries[2]==entries[5]==entries[8] and (entries[2] == "X" or entries[2] == "O"):
        return True
    elif entries[2]==entries[4]==entries[6] and (entries[2] == "X" or entries[2] == "O"):
        return True
    elif entries[3]==entries[4]==entries[5] and (entries[3] == "X" or entries[3] == "O"):
        return True
    elif entries[6]==entries[7]==entries[8] and (entries[6] == "X" or entries[6] == "O"):
        return True
    else:
        return False
    
    
def printBoard(entries):
    print(" {}|{}|{}\n -----\n {}|{}|{}\n -----\n {}|{}|{}\n".format(entries[0],
                                                   entries[1],
                                                   entries[2],
                                                   entries[3],
                                                   entries[4],
                                                   entries[5],
                                                   entries[6],
                                                   entries[7],
                                                   entries[8]))

def inputMove():
    while True:
        try:
            number = int(input("Enter number 1-9:"))
            if number < 1 or number > 9:
                raise ValueError("Not within range of 1-9")
        except ValueError as ve:
            print(ve)
            continue
        else: 
            print ("\n")
            break

    while True:
        try:
            xo = str(input("Enter \"X\" or \"O\":"))
            if xo !="X" and xo !="O":
                raise ValueError("Not X or O")
        except ValueError as ve:
            print(ve)
            continue
        else: 
            print ("\n")
            break

    return [xo,number]

#Starting script
entries = [" "," "," "," "," "," "," "," "," "]
winner = False

while winner == False:
    if determineWinner(entries):
        winner = True

    else:
        move = inputMove()
        entries[move[1]-1]=move[0]
        lastMove = move[0]
        printBoard(entries)
print("Game over. {} wins!".format(lastMove))
# Out:
# Enter number 1-9:1
#
#
# Enter "X" or "O":x
# Not X or O
# Enter "X" or "O":x
# Not X or O
# Enter "X" or "O":X
#
#
#  X| |
#  -----
#   | |
#  -----
#   | |
#
# Enter number 1-9:3
#
#
# Enter "X" or "O":O
#
#
#  X| |O
#  -----
#   | |
#  -----
#   | |
#
# Enter number 1-9:4
#
#
# Enter "X" or "O":X
#
#
#  X| |O
#  -----
#  X| |
#  -----
#   | |
#
# Enter number 1-9:6
#
#
# Enter "X" or "O":O
#
#
#  X| |O
#  -----
#  X| |O
#  -----
#   | |
#
# Enter number 1-9:5
#
#
# Enter "X" or "O":X
#
#
#  X| |O
#  -----
#  X|X|O
#  -----
#   | |
#
# Enter number 1-9:9
#
#
# Enter "X" or "O":O
#
#
#  X| |O
#  -----
#  X|X|O
#  -----
#   | |O
#
# Game over. O wins!
